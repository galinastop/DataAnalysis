# %% [markdown]
# # Google Play Store Apps Project
#
# ### Описание датасета
# > В данном датасете представлена информация о 10 000 приложениях из Play Store
#
# ### Описание задачи
# > 1. Изучить закономерности
# 2. Построить модели для предсказания рейтинга приложения и сравнить их
#
# ### Описание данных
#  - `App` - название приложения
#
#  - `Category` - категория, к которой относится приложение
#
#  - `Rating` - рейтинг приложения на Google Play
#
#  - `Reviews` - количество отзывов пользователей для приложения
#
#  - `Size` - размер приложения
#
#  - `Installs` - количество пользовательских загрузок / установок приложения
#
#  - `Type` - платное или бесплатное : Free / Paid
#
#  - `Price` - стоимость приложения
#
#  - `Content Rating` - возрастная группа, на которую нацелено приложение
#
#  - `Genres` - приложение может принадлежать к нескольким жанрам (кроме его основной категории)
#
#  - `Last Updated` - дата последнего обновления приложения в Play Store
#
#  - `Current Ver` - текущая версия приложения
#
#  - `Android Ver` - минимальная требуемая версия Android
#
#  **Ссылка на датасет**
#  https://www.kaggle.com/lava18/google-play-store-apps?select=googleplaystore.csv

# %% [markdown]
# ### Функция отрисовки AUC кривой
# **ROC-кривая** — график, который позволяет оценить качество бинарной классификации. График показывает зависимость **TPR**(True Positive Rate) от **FPR**(False Positive Rate) при варьировании порога. В точке `(0,0)` порог минимален, точно так же минимальны и **TPR** и **FPR**. Идеальным случаем для классификатора является проход графика через точку `(0,1)`.
#
# Полнота **TPR** (**T**rue **p**ositive **r**ate) - доля верно классифицированных положительных примеров среди всех положительных примеров.
#
# **FPR** (**F**alse **p**ositive **r**ate) - доля ошибочно классифицированных отрицательных примеров среди всех отрицательных примеров.
#
# **AUC (Area Under Curve)** — данный термин (площадь под графиком) даёт количественную характеристику **ROC-кривой**: чем больше — тем лучше. **AUC** — эквивалентна вероятности, что классификатор присвоит большее значение случайно выбранному позитивному объекту, чем случайно выбранному негативному объекту.
#
# Когда **AUC = 0.5**, то данный классификатор равен случайному.

# %%
def show_auc(predict):
    fpr, tpr, threshold = metrics.roc_curve(y_test, predict)
    roc_auc = metrics.auc(fpr, tpr)

    plt.title('ROC')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# **Импортируем нужные библиотеки**

# %%
import numpy as np
import pandas as pd
import pylab as pl
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate, GridSearchCV, train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import linear_model, metrics, pipeline, preprocessing
from sklearn.metrics import matthews_corrcoef
from graphviz import Source
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("googleplaystore.csv")

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# **Избавимся от повторяющихся данных**

# %%
data[data.duplicated()].count()
# Out:
# App               483
# Category          483
# Rating            474
# Reviews           483
# Size              483
# Installs          483
# Type              483
# Price             483
# Content Rating    483
# Genres            483
# Last Updated      483
# Current Ver       483
# Android Ver       483
# dtype: int64

# %%
data=data.drop_duplicates()
data[data.duplicated()].count()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Исследуем каждый признак по отдельности
#
# ### Category

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# - Заметим, что присутствует некорретное значение категории `1.9`. Также заметим, что помимо неккорректной категории, остальные данные тоже введены некорректно, поэтому просто избавимся от этого наблюдения.

# %%
data[data['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data = data.drop([10472])

# %%
plt.figure(figsize=(10,10))
g = sns.countplot(y="Category",data=data, palette = "Set2")
plt.title('Кол-во приложений каждой категории',size = 20)
# Out:
# Text(0.5, 1.0, 'Кол-во приложений каждой категории')

# %%
fig = plt.figure(figsize=(16,8)) 
data.groupby('Category').mean().sort_values(by='Rating',ascending='False')['Rating'].plot(kind='bar',title='Average app rating', fontsize=10)
plt.ylabel('Star Rating') 
plt.style.use('seaborn-white')

# %% [markdown]
# ### Reviews
# Преобразуем значения в числовой тип с помощью функции `to_numeric` из библиотеки `pandas`
# - `coerce` означает, что если значение не удается преобразовать в числовой тип, то ставится NaN

# %%
data['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
data['Reviews'] = pd.to_numeric(data['Reviews'],errors='coerce')

# %% [markdown]
# ### Size

# %%
data['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# - Размер приложения преобразуем в килобайты; значение `Varies with device` заменим на `NaN`

# %%
data['Size'].replace('Varies with device', np.nan, inplace = True ) 
data['Size']=data['Size'].str.extract(r'([\d\.]+)', expand=False).astype(float) * \
    data['Size'].str.extract(r'([kM]+)', expand=False).fillna(1).replace(['k','M'],[1,1000]).astype(int)

# %%
res = data.groupby('Category')['Size'].sum().reset_index()
finaldata = res.sort_values('Size', ascending=False).reset_index(drop=True)

ind = finaldata.set_index("Category", inplace = True)
bar = finaldata.plot(kind='bar',figsize=(30, 16), color = "blue", legend = None)
plt.yticks(fontsize = 24)
plt.xticks(fontsize = 20)
plt.xlabel("Category", fontsize = 20)
plt.ylabel("Size", fontsize = 20)
# Out:
# Text(0, 0.5, 'Size')

# %% [markdown]
# ### Installs
# Просто избавимся от `+` и преобразуем в числовой тип

# %%
data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
data['Installs']=data['Installs'].str.replace(r'\D','').astype(float)

# %%
res = data.groupby('Category')['Installs'].sum().reset_index()
final_result = res.sort_values(by = 'Installs', ascending = False).head(10)
plt.bar("Category", "Installs", data = final_result, color = "blue")
plt.xlabel("Категория")
plt.xticks(rotation = 90)
plt.ylabel("Кол-во установок")
plt.title("Топ 10 категорий, с наибольшим кол-вом установок")
plt.show()

# %% [markdown]
# > **Заметим, что больше скачиваний для игр и мессенджеров**

# %% [markdown]
# ### Price
# Избавимся от знака `$`

# %%
data['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
data['Price']=data['Price'].str.replace('$','').astype(float)

# %%
fig = plt.figure(figsize=(16,8)) 
data.groupby('Category').mean().sort_values(by='Price',ascending='Price')['Price'].plot(kind='bar',title='Стоимость, $', fontsize=10)
plt.ylabel('Средняя стоимость, $')
# Out:
# Text(0, 0.5, 'Средняя стоимость, $')

# %% [markdown]
# ### Type
# Преобразуем в бинарный тип, то есть значению `Free` поставим значение `0` ; значению `Paid` - `1`

# %%
labels =data['Type'].value_counts(sort = True).index
sizes = data['Type'].value_counts(sort = True)


colors = ["lightblue","orangered"]
explode = (0.1,0)  # explode 1st slice
 
rcParams['figure.figsize'] = 5,5
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=150,)

plt.title('Процент бесплатных приложений', size = 15)
plt.show()

# %%
data.Type.unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
data['Type'] = data['Type'].str.replace('Free','0')
data['Type'] = data['Type'].str.replace('Paid','1').astype(float)

# %%
data[data.Type.isnull()]
# Out:
#                             App Category  Rating  Reviews  Size  Installs  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN        0   NaN       0.0
#
#       Type  Price Content Rating    Genres   Last Updated         Current Ver  \
# 9148   NaN    0.0   Everyone 10+  Strategy  June 28, 2018  Varies with device
#
#              Android Ver
# 9148  Varies with device

# %% [markdown]
# Заменим отсутствующее значение на 0, т.к. `Price` = 0.0; преобразуем из типа `float` в `int`

# %%
data.loc[9148, 'Type'] = 0
data['Type'] = data['Type'].astype(int)

# %% [markdown]
# ### Content Rating

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size    Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000.0     0    0.0       Everyone
# 1      967  14000.0    500000.0     0    0.0       Everyone
# 2    87510   8700.0   5000000.0     0    0.0       Everyone
# 3   215644  25000.0  50000000.0     0    0.0           Teen
# 4      967   2800.0    100000.0     0    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
data[data['Content Rating']=='Unrated']
# Out:
#                          App Category  Rating  Reviews    Size  Installs  \
# 7312     Best CG Photography   FAMILY     NaN        1  2500.0     500.0
# 8266  DC Universe Online Map    TOOLS     4.1     1186  6400.0   50000.0
#
#       Type  Price Content Rating         Genres       Last Updated  \
# 7312     0    0.0        Unrated  Entertainment      June 24, 2015
# 8266     0    0.0        Unrated          Tools  February 27, 2012
#
#      Current Ver   Android Ver
# 7312         5.2    3.0 and up
# 8266         1.3  2.3.3 and up

# %% [markdown]
# Удалим наблюдения, у который неизвестна возрастная группа

# %%
data = data.drop([7312,8266])

# %%
labels=data['Content Rating'].unique()
explode = (0, 0, 0, 0, 0.1)
size=list()
for content in labels:
    size.append(data[data['Content Rating']==content]['Installs'].count())

plt.figure(figsize=(10,10))
plt.pie(size, explode=explode, labels=labels,autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Процент скачиваний для каждой возрастной группы',size = 20)
plt.show()

# %% [markdown]
# Больше всего скачиваний у приложений без ограничений

# %% [markdown]
# ### Genres

# %%
data.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
data.Genres.value_counts().tail(10)
# Out:
# Strategy;Creativity                    1
# Health & Fitness;Education             1
# Health & Fitness;Action & Adventure    1
# Board;Pretend Play                     1
# Role Playing;Brain Games               1
# Adventure;Brain Games                  1
# Strategy;Education                     1
# Parenting;Brain Games                  1
# Role Playing;Education                 1
# Music & Audio;Music & Video            1
# Name: Genres, dtype: int64

# %% [markdown]
# Многие жанры содержат несколько записей. Сгруппируем жанры, игнорируя суб-жанры

# %%
data['Genres'] = data['Genres'].str.split(';').str[0]

# %%
data.Genres.value_counts().tail(10)
# Out:
# Board            63
# Comics           60
# Parenting        60
# Beauty           53
# Card             51
# Casino           39
# Trivia           39
# Word             28
# Music            24
# Music & Audio     1
# Name: Genres, dtype: int64

# %% [markdown]
# Объединим `Music & Audio` и `Music`

# %%
data['Genres'].replace('Music & Audio', 'Music',inplace = True)

# %% [markdown]
# ### Last Updated
# - Введем новую переменную, которая является разницей между последней обновленной датой и сегодняшним днем

# %%
from datetime import datetime,date
temp=pd.to_datetime(data['Last Updated'])
temp.head()
# Out:
# 0   2018-01-07
# 1   2018-01-15
# 2   2018-08-01
# 3   2018-06-08
# 4   2018-06-20
# Name: Last Updated, dtype: datetime64[ns]

# %%
data['Last_Updated_Days'] = temp.apply(lambda x:((date.today()-datetime.date(x)).days))
data.Last_Updated_Days.head()
# Out:
# 0    869
# 1    861
# 2    663
# 3    717
# 4    705
# Name: Last_Updated_Days, dtype: int64

# %%
data.drop(['Last Updated'], axis='columns', inplace=True)

# %% [markdown]
# ### Android Ver
# Большинство значений имеют верхнее значение и нижнее значение (т. е. диапазон), заменим на нижнее значение версии

# %%
data['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
data['Version_begin']=data['Android Ver'].apply(lambda x:str(x).split(' and ')[0].split(' - ')[0])
data.Version_begin=data.Version_begin.replace('4.4W','4.4')
data['Version_begin'].replace('Varies with device', np.nan, inplace = True)
data['Version_begin'].replace('nan', np.nan, inplace = True )

# %%
data['Version_begin'].unique()
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', nan,
#        '2.2', '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '2.0', '3.2', '7.1', '8.0', '3.1', '2.0.1', '1.0'], dtype=object)

# %%
data['Version_begin'].replace('4.0.3', '4.0', inplace = True )
data['Version_begin'].replace('2.3.3', '2.3', inplace = True )
data['Version_begin'].replace('2.0.1', '2.1', inplace = True )

# %%
data['Version_begin'] = data['Version_begin'].astype(float)

# %%
data.drop(['Android Ver'], axis='columns', inplace=True)

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size    Installs  Type  Price Content Rating        Genres  \
# 0      159  19000.0     10000.0     0    0.0       Everyone  Art & Design
# 1      967  14000.0    500000.0     0    0.0       Everyone  Art & Design
# 2    87510   8700.0   5000000.0     0    0.0       Everyone  Art & Design
# 3   215644  25000.0  50000000.0     0    0.0           Teen  Art & Design
# 4      967   2800.0    100000.0     0    0.0       Everyone  Art & Design
#
#           Current Ver  Last_Updated_Days  Version_begin
# ...

# %% [markdown]
# #### Проверим корреляции между признаками

# %%
plt.subplots(figsize=(17, 17))
sns.heatmap(data.corr(), annot=True, fmt= '.2f')
plt.show()

# %% [markdown]
# > переменные `Installs` и `Reviews` коррелирует между собой, это можно объяснить тем, что чем больше людей скачает приложение, тем больше будет отзывов

# %% [markdown]
# ## Пропущенные значения

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(data.isnull(), cmap='viridis')
data.isnull().sum()
# Out:
# App                     0
# Category                0
# Rating               1464
# Reviews                 0
# Size                 1526
# Installs                0
# Type                    0
# Price                   0
# Content Rating          0
# Genres                  0
# Current Ver             8
# Last_Updated_Days       0
# Version_begin        1223
# dtype: int64

# %% [markdown]
# Заменим пропущенные значения на медиану

# %%
data['Rating'] = data['Rating'].fillna(data['Rating'].median())
data['Size'] = data['Size'].fillna(data['Size'].median())
data['Version_begin'] = data['Version_begin'].fillna(data['Version_begin'].median())

# %% [markdown]
# ## Категориальные данные

# %%
CategoryList = data['Category'].unique().tolist() 
CategoryList = ['cat_' + word for word in CategoryList]
data = pd.concat([data, pd.get_dummies(data['Category'], prefix='cat')], axis=1)

# %%
LE = preprocessing.LabelEncoder()
data['Genres'] = LE.fit_transform(data['Genres'])

# %%
LE = preprocessing.LabelEncoder()
data['Content Rating'] = LE.fit_transform(data['Content Rating'])

# %% [markdown]
#   #### Добавим бинарный целевой признак, `isPopular` :
#    если `Rating >= 4`, то признак будет иметь значение **1**
#
#    иначе **0**

# %%
data['isPopular']=data['Rating']
data.loc[data['Rating']>=4, 'isPopular'] = 1
data.loc[~(data['Rating']>=4), 'isPopular'] = 0
data['isPopular'] = data['isPopular'].astype(int)

# %% [markdown]
# ### Разбиение на обучение и контроль

# %%
y = data['isPopular']
X = data.drop(['App', 'Category', 'Current Ver', 'Rating', 'isPopular'], axis=1)

# %% [markdown]
# Проверим выборку на сбалансированность. Заметим, что в выборке больше наблюдений имеющих значение целевого признака `1`.

# %%
plt.figure(figsize=(12,8))
sns.countplot(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.columns
# Out:
# Index(['Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating',
#        'Genres', 'Last_Updated_Days', 'Version_begin', 'cat_ART_AND_DESIGN',
#        'cat_AUTO_AND_VEHICLES', 'cat_BEAUTY', 'cat_BOOKS_AND_REFERENCE',
#        'cat_BUSINESS', 'cat_COMICS', 'cat_COMMUNICATION', 'cat_DATING',
#        'cat_EDUCATION', 'cat_ENTERTAINMENT', 'cat_EVENTS', 'cat_FAMILY',
#        'cat_FINANCE', 'cat_FOOD_AND_DRINK', 'cat_GAME',
#        'cat_HEALTH_AND_FITNESS', 'cat_HOUSE_AND_HOME',
#        'cat_LIBRARIES_AND_DEMO', 'cat_LIFESTYLE', 'cat_MAPS_AND_NAVIGATION',
#        'cat_MEDICAL', 'cat_NEWS_AND_MAGAZINES', 'cat_PARENTING',
#        'cat_PERSONALIZATION', 'cat_PHOTOGRAPHY', 'cat_PRODUCTIVITY',
#        'cat_SHOPPING', 'cat_SOCIAL', 'cat_SPORTS', 'cat_TOOLS',
#        'cat_TRAVEL_AND_LOCAL', 'cat_VIDEO_PLAYERS', 'cat_WEATHER'],
#       dtype='object')

# %% [markdown]
# ### Дерево решений с подбором параметров
# **Дерево принятия решений** (также может называться деревом классификации или регрессионным деревом) — средство поддержки принятия решений. Структура дерева представляет собой «листья» и «ветки». На рёбрах («ветках») дерева решения записаны атрибуты, от которых зависит целевая функция, в «листьях» записаны значения целевой функции, а в остальных узлах — атрибуты, по которым различаются случаи. Чтобы классифицировать новый случай, надо спуститься по дереву до листа и выдать соответствующее значение.

# %%
tree=DecisionTreeClassifier(random_state=17)
tree_params = {'max_depth': list(range(5,15)), 
               'min_samples_leaf': list(range(1,19)),
               'criterion': ('entropy','gini')}

tree_grid = GridSearchCV(tree, tree_params,
                         cv=5, n_jobs=-1,
                        verbose=True)
tree_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 1024 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 1800 out of 1800 | elapsed:   14.1s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
# ...

# %%
tree_grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5}

# %%
tree_grid.best_score_
# Out:
# 0.8138796909492274

# %%
predict = tree_grid.predict_proba(X_test)[:,1]

# %%
show_auc(predict)

# %% [markdown]
# **Построим дерево по найденным параметрам**

# %%
from os import system
tree2=DecisionTreeClassifier(max_depth=6,criterion='entropy', min_samples_leaf=5)
tree2.fit(X_train, y_train)
dotfile = open(r'tree.dot', 'w')

graph = Source(export_graphviz(tree2, out_file=dotfile, 
               rounded = True, proportion = False, 
                precision = 2, filled = True))
dotfile.close()
system("dot -Tpng tree.dot -o tree.png")
# Out:
# 0

# %% [markdown]
# >- Первое разбиение происходит по признаку `Reviews<=42661`
# - Второе разбиение по признакам `Reviews<=173000` и `Installs<=300`

# %% [markdown]
# ### Случайный лес с подбором параметров
#
# **RF (random forest)** — это множество решающих деревьев. В задаче регрессии их ответы усредняются, в задаче классификации принимается решение голосованием по большинству. Все деревья строятся независимо.

# %%
forest_params = {'max_depth': list(range(10,18)), 'min_samples_leaf': list(range(16,20))}
forest = RandomForestClassifier(random_state=17, n_estimators=600)
best_forest = GridSearchCV(forest, forest_params, cv=5, n_jobs=-1)
best_forest.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=600, n_jobs=None,
#                                               oob_score=False, random_state=17,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
# ...

# %%
best_forest.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 16}

# %%
best_forest.best_score_
# Out:
# 0.8136037527593819

# %%
predict2 = best_forest.predict_proba(X_test)[:,1]
show_auc(predict2)

# %% [markdown]
# ### Bagging
# **Бэггинг (баггинг)** - от англ. **B**ootstrap **agg**regat**ing**, это технология классификации, использующая композиции алгоритмов, каждый из которых обучается независимо. Результат классификации определяется путем голосования. Бэггинг позволяет снизить процент ошибки классификации в случае, когда высока дисперсия ошибки базового метода.
#
# **Бэггинг** – технология классификации, где в отличие от бустинга все элементарные классификаторы обучаются и работают параллельно (независимо друг от друга). Идея заключается в том, что классификаторы не исправляют ошибки друг друга, а компенсируют их при голосовании. Базовые классификаторы должны быть независимыми, это могут быть классификаторы основанные на разных группах методов или же обученные на независимых наборах данных. Во втором случае можно использовать один и тот же метод.
#
# > `n_estimators` - число деревьев.
# >
# > `random_state` - Генератор рандомных чисел, которые используются при построении модели и влияют на ее веса\коэффициенты, по которым потом вычисляется предсказание.
# >
# > `oob_score` - Следует ли использовать готовые образцы для оценки ошибки обобщения.
# >
# > `n_jobs` - по умолчанию стоит 1, но для распределения по ядрам устанавливаем -1.
# >
# > `bootstrap` - отрисованы ли множества с заменой. Если False, выполняется выборка без замены.

# %%
from sklearn.ensemble import BaggingClassifier
bag_model = BaggingClassifier(n_estimators=600,
                          n_jobs=-1,
                          random_state=4,
                          oob_score=True,
                          bootstrap=True)
bag_model.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                   max_features=1.0, max_samples=1.0, n_estimators=600,
#                   n_jobs=-1, oob_score=True, random_state=4, verbose=0,
#                   warm_start=False)

# %%
predict3 = bag_model.predict_proba(X_test)[:,1]
show_auc(predict3)

# %% [markdown]
# ### Градиентный бустинг
# > `n_estimators` - Число шагов.
# >
# > `learning_rate` - Параметр, который масштабирует длину шага процедуры градиентного спуска.
# >
# > `random_state` - Генератор случайнных чисел, которые используются при построении модели и влияют на ее веса\коэффициенты, по которым потом вычисляется предсказание.
# >
# > `max_depth` - Максимальная глубина 3.
# >
# > `max_features` - Задача классификации при построении этого ансамбля деревьев рекомендует брать квадратный корень из всех признаков, чтобы деревья были более разнообразными.
# >
# > `warm_start` - Параметр типа bool. Если True, повторно использовать решения предыдущего вызова для подгонки и добавить дополнительные оценки в ансамбль, в противном случае просто подгонять целый новый ансамбль
# >
# > `criterion` (по стандарту `friedman_mse`) - Функция для измерения качества разделения.
# >
# Значение по умолчанию `friedman_mse`, как правило, является наилучшим, поскольку в некоторых случаях оно может обеспечить лучшее приближение.

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradient = GradientBoostingClassifier(n_estimators=600,
                                   learning_rate=0.1,
                                   max_features='sqrt',
                                   warm_start=True,
                                   random_state=4,
                                   max_depth=3,
                                   criterion='friedman_mse')
gradient.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features='sqrt', max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=600,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=4, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0, warm_start=True)

# %%
predict4 = gradient.predict_proba(X_test)[:,1]
show_auc(predict4)

# %% [markdown]
# ## Выводы:
# - Наибольшее количество приложений, находящихся на Google Play, представляются жанрами: `Family`  `Games`  `Tools`
# - Рейтинг не сильно зависит от категории приложения
# - Наибольшая средняя стоимость у приложений данных категорий: `Finance`  `Lifestyle`  `Medical`
# - Наиболее скачиваемые приложения категорий: `Game`  `Communication`  `Social` и без возрастных категорий
# - Наиболее 'тяжелые приложения' категорий: `Game`  `Family`
#
# ----
#
# - Лучшее значение **AUC** показал градиентный бустинг
